# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import os
from matplotlib.cm import get_cmap
import datetime

plt.rc('font', family='serif')
plt.rc('axes', labelsize=16)
plt.rc('xtick', labelsize=14, color='grey')
plt.rc('ytick', labelsize=14, color='grey')
plt.rc('legend', fontsize=16, loc='lower left')
plt.rc('figure', titlesize=18)
plt.rc('savefig', dpi=330, bbox='tight')
# %matplotlib inline

# %%
data_dir = '../data'
data_file = 'zone_temp_exterior_raw.csv'

path_to_data = os.path.join(data_dir, data_file)
data = pd.read_csv(path_to_data, index_col=0)

data.index = pd.to_datetime(data.index)
data.index = data.index.tz_convert("America/Los_Angeles")

data = data.resample('1T').mean()

# %%
data = pd.DataFrame(columns = data.columns,
                    index = data.index,
                    data = (data.values-32)*5/9,
                    dtype = np.float32)

# %%
from util import generate_fig_name, plot_FS

# %% [markdown]
# ## Fouries Series

# %%
sensor_index = 'zone_028_temp'

# %% [markdown]
# ### With high frequency components

# %%
date_start = datetime.date(2019, 2, 26)
date_end = date_start + datetime.timedelta(days=1)

data_array = data.loc[date_start:date_end,sensor_index]
data_array
# Out:
# C:\Users\CEZHEW~1\AppData\Local\Temp/ipykernel_4644/2110848455.py:4: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   data_array = data.loc[date_start:date_end,sensor_index]
# 2019-02-26 00:00:00-08:00    21.611111
# 2019-02-26 00:01:00-08:00    21.611111
# 2019-02-26 00:02:00-08:00    21.611111
# 2019-02-26 00:03:00-08:00    21.444445
# 2019-02-26 00:04:00-08:00    21.444445
#                                ...
# 2019-02-26 23:56:00-08:00    21.444445
# 2019-02-26 23:57:00-08:00    21.444445
# 2019-02-26 23:58:00-08:00    21.611111
# 2019-02-26 23:59:00-08:00    21.611111
# 2019-02-27 00:00:00-08:00    21.611111
# Freq: T, Name: zone_028_temp, Length: 1441, dtype: float32

# %%
plot_FS(data_array.values, f"{sensor_index.split('_')[1]}_high_frequency_190226")

# %% [markdown]
# ### With medium frequency components

# %%
date_start = datetime.date(2020, 12, 28)
date_end = date_start + datetime.timedelta(days=1)

data_array = data.loc[date_start:date_end,sensor_index]
data_array
# Out:
# C:\Users\CEZHEW~1\AppData\Local\Temp/ipykernel_4644/76379987.py:4: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   data_array = data.loc[date_start:date_end,sensor_index]
# 2020-12-28 00:00:00-08:00    19.333334
# 2020-12-28 00:01:00-08:00    19.333334
# 2020-12-28 00:02:00-08:00    19.333334
# 2020-12-28 00:03:00-08:00    19.333334
# 2020-12-28 00:04:00-08:00    19.333334
#                                ...
# 2020-12-28 23:56:00-08:00    18.944445
# 2020-12-28 23:57:00-08:00    18.944445
# 2020-12-28 23:58:00-08:00    18.944445
# 2020-12-28 23:59:00-08:00    18.944445
# 2020-12-29 00:00:00-08:00    18.944445
# Freq: T, Name: zone_028_temp, Length: 1441, dtype: float32

# %%
plot_FS(data_array.values, f"{sensor_index.split('_')[1]}_medium_frequency_201228")

# %% [markdown]
# ### With low frequency components

# %%
date_start = datetime.date(2020, 12, 30)
date_end = date_start + datetime.timedelta(days=1)

data_array = data.loc[date_start:date_end,sensor_index]
data_array
# Out:
# C:\Users\CEZHEW~1\AppData\Local\Temp/ipykernel_4644/1261462075.py:4: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   data_array = data.loc[date_start:date_end,sensor_index]
# 2020-12-30 00:00:00-08:00    19.500000
# 2020-12-30 00:01:00-08:00    19.500000
# 2020-12-30 00:02:00-08:00    19.500000
# 2020-12-30 00:03:00-08:00    19.388889
# 2020-12-30 00:04:00-08:00    19.388889
#                                ...
# 2020-12-30 23:56:00-08:00    19.333334
# 2020-12-30 23:57:00-08:00    19.333334
# 2020-12-30 23:58:00-08:00    19.333334
# 2020-12-30 23:59:00-08:00    19.333334
# 2020-12-31 00:00:00-08:00    19.333334
# Freq: T, Name: zone_028_temp, Length: 1441, dtype: float32

# %%
plot_FS(data_array.values, f"{sensor_index.split('_')[1]}_low_frequency_201230")
